# %%
import pandas as pd

emprestimos = pd.read_parquet('../dados_raw/emprestimos_completos.parquet')
emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                           None
# 1         709685       L167050                           None
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# Identificar CDU com base na coluna localizacao

# %%
def identifica_cdu(linha):
    if linha in range(100, 200):
        return "Filosofia e psicologia."
    elif linha in range(200, 300):
        return "Religião."
    elif linha in range(300, 400):
        return "Ciências sociais."
    elif linha in range(500, 600):
        return "Matemática e ciências naturais."
    elif linha in range(600, 700):
        return "Ciências aplicadas."
    elif linha in range(700, 800):
        return "Belas artes."
    elif linha in range(800, 900):
        return "Linguagem. Língua. Linguística."
    elif linha in range(900, 1000):
        return "Geografia. Biografia. História."

# %% [markdown]
# Aplicando a função de identificar CDU ao dataframe

# %%
emprestimos['Nome CDU'] = emprestimos['localizacao'].apply(identifica_cdu)

# %% [markdown]
# Remover coluna não usada

# %%
emprestimos = emprestimos.drop(labels='registro_sistema',axis=1)
emprestimos.head(1)
# Out:
#    id_emprestimo codigo_barras data_renovacao                data_emprestimo  \
# 0         709684       L095049           None  2010/01/04 07:44:10.721000000
#
#                   data_devolucao  matricula_ou_siape tipo_vinculo_usuario  \
# 0  2010/01/05 16:26:12.662000000        2.008023e+09   ALUNO DE GRADUAÇÃO
#
#    id_exemplar            colecao                      biblioteca  \
# 0        13259  Acervo Circulante  Biblioteca Central Zila Mamede
#
#   status_material  localizacao             Nome CDU
# 0         REGULAR          630  Ciências aplicadas.

# %% [markdown]
# Formatar coluna matricula_ou_siape

# %%
emprestimos['matricula_ou_siape'] = emprestimos['matricula_ou_siape'].astype('str')
emprestimos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                           None
# 1         709685       L167050                           None
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...
